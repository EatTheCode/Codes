# %% [markdown]
# RGB 컬러 영상에서 Feature map에서는 각각의 필터를 생성하여 결과값을 구한후에 그합을 구한다
#
# 풀링레이어는 정해놓은 크기의 대표값을 뽑아내는것
#
# 하나의 conv2d로 들어가서 각각의 채널에 맞게 각각의 필터가 개별적으로 들어간다
#
# RGB 컬러 영상에서 Feature map에서는 각각의 필터를 생성하여 결과값을 구한후에 그합을 구한다
#
# 풀링레이어는 정해놓은 크기의 대표값을 뽑아내는것
#
# 하나의 conv2d로 들어가서 각각의 채널에 맞게 각각의 필터가 개별적으로 들어간다
#
# 파라미터 갯수 구하기
# 풀링레이어는 정해놓은 크기의 대표값을 뽑아내는것
#
# 하나의 conv2d로 들어가서 각각의 채널에 맞게 각각의 필터가 개별적으로 들어간다
#
# 파라미터 갯수 구하기
# dense 는 뽑혀진 feature를 분류
