# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-1-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Anaconda3\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 30            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층, 5X5X32 필터
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev=0.01))  
#W2 = tf.Variable(tf.random_normal([5, 5, 1, 32]))  
#b2 = tf.Variable(tf.constant(0.1, shape=[32]))  
b2 = tf.Variable(tf.random_normal([32])) 

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 14X14 크기를 가진 32개의 activation map을 flatten 시킴
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
# 출력층
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev=0.01))
#W3 = tf.Variable(tf.random_normal([14*14*32, 10]))
b3 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z3, 즉 softmax 에 들어가는 입력 값
Z3 = logits = tf.matmul(A2_flat, W3) + b3    # 선형회귀 값 Z3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A3, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A3, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 50 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.7350626
# epochs =  0 , step =  100 , loss_val =  0.5090084
# epochs =  0 , step =  200 , loss_val =  0.3591749
# epochs =  0 , step =  300 , loss_val =  0.40368888
# epochs =  0 , step =  400 , loss_val =  0.48307198
# epochs =  0 , step =  500 , loss_val =  0.37358978
# epochs =  1 , step =  0 , loss_val =  0.21785757
# epochs =  1 , step =  100 , loss_val =  0.2645036
# epochs =  1 , step =  200 , loss_val =  0.13284065
# epochs =  1 , step =  300 , loss_val =  0.24669366
# epochs =  1 , step =  400 , loss_val =  0.09970439
# epochs =  1 , step =  500 , loss_val =  0.08242004
# epochs =  2 , step =  0 , loss_val =  0.095352046
# epochs =  2 , step =  100 , loss_val =  0.15006094
# epochs =  2 , step =  200 , loss_val =  0.08739092
# epochs =  2 , step =  300 , loss_val =  0.06122506
# epochs =  2 , step =  400 , loss_val =  0.1186985
# epochs =  2 , step =  500 , loss_val =  0.04838783
# epochs =  3 , step =  0 , loss_val =  0.047051504
# epochs =  3 , step =  100 , loss_val =  0.049132988
# epochs =  3 , step =  200 , loss_val =  0.04646143
# epochs =  3 , step =  300 , loss_val =  0.064844385
# epochs =  3 , step =  400 , loss_val =  0.11387148
# epochs =  3 , step =  500 , loss_val =  0.11154482
# epochs =  4 , step =  0 , loss_val =  0.027137073
# epochs =  4 , step =  100 , loss_val =  0.037081193
# epochs =  4 , step =  200 , loss_val =  0.08586796
# epochs =  4 , step =  300 , loss_val =  0.12765473
# epochs =  4 , step =  400 , loss_val =  0.114763215
# epochs =  4 , step =  500 , loss_val =  0.17990145
# epochs =  5 , step =  0 , loss_val =  0.08121687
# epochs =  5 , step =  100 , loss_val =  0.029245697
# epochs =  5 , step =  200 , loss_val =  0.08209221
# epochs =  5 , step =  300 , loss_val =  0.07459077
# epochs =  5 , step =  400 , loss_val =  0.10996336
# epochs =  5 , step =  500 , loss_val =  0.1462596
# epochs =  6 , step =  0 , loss_val =  0.03133808
# epochs =  6 , step =  100 , loss_val =  0.09318545
# epochs =  6 , step =  200 , loss_val =  0.08149806
# epochs =  6 , step =  300 , loss_val =  0.06039381
# epochs =  6 , step =  400 , loss_val =  0.031509347
# epochs =  6 , step =  500 , loss_val =  0.020971324
# epochs =  7 , step =  0 , loss_val =  0.004208177
# epochs =  7 , step =  100 , loss_val =  0.050917808
# epochs =  7 , step =  200 , loss_val =  0.044450805
# epochs =  7 , step =  300 , loss_val =  0.07606246
# epochs =  7 , step =  400 , loss_val =  0.1158143
# epochs =  7 , step =  500 , loss_val =  0.010260598
# epochs =  8 , step =  0 , loss_val =  0.03353106
# epochs =  8 , step =  100 , loss_val =  0.036629084
# epochs =  8 , step =  200 , loss_val =  0.037941333
# epochs =  8 , step =  300 , loss_val =  0.08290614
# epochs =  8 , step =  400 , loss_val =  0.16784605
# epochs =  8 , step =  500 , loss_val =  0.10747681
# epochs =  9 , step =  0 , loss_val =  0.017861797
# epochs =  9 , step =  100 , loss_val =  0.03341695
# epochs =  9 , step =  200 , loss_val =  0.024679314
# epochs =  9 , step =  300 , loss_val =  0.061272856
# epochs =  9 , step =  400 , loss_val =  0.011840606
# epochs =  9 , step =  500 , loss_val =  0.06366456
# epochs =  10 , step =  0 , loss_val =  0.035807267
# epochs =  10 , step =  100 , loss_val =  0.022027455
# epochs =  10 , step =  200 , loss_val =  0.08847171
# epochs =  10 , step =  300 , loss_val =  0.038561203
# epochs =  10 , step =  400 , loss_val =  0.08766735
# epochs =  10 , step =  500 , loss_val =  0.0033386063
# epochs =  11 , step =  0 , loss_val =  0.12037668
# epochs =  11 , step =  100 , loss_val =  0.04058856
# epochs =  11 , step =  200 , loss_val =  0.00641101
# epochs =  11 , step =  300 , loss_val =  0.013569765
# epochs =  11 , step =  400 , loss_val =  0.041420363
# epochs =  11 , step =  500 , loss_val =  0.06757589
# epochs =  12 , step =  0 , loss_val =  0.0074498667
# epochs =  12 , step =  100 , loss_val =  0.06560844
# epochs =  12 , step =  200 , loss_val =  0.03813081
# epochs =  12 , step =  300 , loss_val =  0.057908155
# epochs =  12 , step =  400 , loss_val =  0.046358928
# epochs =  12 , step =  500 , loss_val =  0.15995647
# epochs =  13 , step =  0 , loss_val =  0.0085784225
# epochs =  13 , step =  100 , loss_val =  0.0038501536
# epochs =  13 , step =  200 , loss_val =  0.020580411
# epochs =  13 , step =  300 , loss_val =  0.006976487
# epochs =  13 , step =  400 , loss_val =  0.031133316
# epochs =  13 , step =  500 , loss_val =  0.012296212
# epochs =  14 , step =  0 , loss_val =  0.04807101
# epochs =  14 , step =  100 , loss_val =  0.017564584
# epochs =  14 , step =  200 , loss_val =  0.060084604
# epochs =  14 , step =  300 , loss_val =  0.020852394
# epochs =  14 , step =  400 , loss_val =  0.08703997
# epochs =  14 , step =  500 , loss_val =  0.03932864
# epochs =  15 , step =  0 , loss_val =  0.013181347
# epochs =  15 , step =  100 , loss_val =  0.101576716
# epochs =  15 , step =  200 , loss_val =  0.0186098
# epochs =  15 , step =  300 , loss_val =  0.0070918696
# epochs =  15 , step =  400 , loss_val =  0.021474814
# epochs =  15 , step =  500 , loss_val =  0.007154914
# epochs =  16 , step =  0 , loss_val =  0.028623326
# epochs =  16 , step =  100 , loss_val =  0.104220696
# epochs =  16 , step =  200 , loss_val =  0.011334213
# epochs =  16 , step =  300 , loss_val =  0.012196093
# epochs =  16 , step =  400 , loss_val =  0.04204678
# epochs =  16 , step =  500 , loss_val =  0.007553029
# epochs =  17 , step =  0 , loss_val =  0.04637167
# epochs =  17 , step =  100 , loss_val =  0.0077201817
# epochs =  17 , step =  200 , loss_val =  0.018021768
# epochs =  17 , step =  300 , loss_val =  0.018735277
# epochs =  17 , step =  400 , loss_val =  0.048373807
# epochs =  17 , step =  500 , loss_val =  0.117679834
# epochs =  18 , step =  0 , loss_val =  0.0053169616
# epochs =  18 , step =  100 , loss_val =  0.003114531
# epochs =  18 , step =  200 , loss_val =  0.11186713
# epochs =  18 , step =  300 , loss_val =  0.14209172
# epochs =  18 , step =  400 , loss_val =  0.017854027
# epochs =  18 , step =  500 , loss_val =  0.04018242
# epochs =  19 , step =  0 , loss_val =  0.026413975
# epochs =  19 , step =  100 , loss_val =  0.0166147
# epochs =  19 , step =  200 , loss_val =  0.040575538
# epochs =  19 , step =  300 , loss_val =  0.052522354
# epochs =  19 , step =  400 , loss_val =  0.01921981
# epochs =  19 , step =  500 , loss_val =  0.01079616
# epochs =  20 , step =  0 , loss_val =  0.0024560932
# epochs =  20 , step =  100 , loss_val =  0.003321318
# epochs =  20 , step =  200 , loss_val =  0.0030616648
# epochs =  20 , step =  300 , loss_val =  0.015314531
# epochs =  20 , step =  400 , loss_val =  0.0123861125
# epochs =  20 , step =  500 , loss_val =  0.009802842
# epochs =  21 , step =  0 , loss_val =  0.010641541
# epochs =  21 , step =  100 , loss_val =  0.0010394672
# epochs =  21 , step =  200 , loss_val =  0.00060624117
# epochs =  21 , step =  300 , loss_val =  0.004770541
# epochs =  21 , step =  400 , loss_val =  0.020085717
# epochs =  21 , step =  500 , loss_val =  0.03505221
# epochs =  22 , step =  0 , loss_val =  0.0072330814
# epochs =  22 , step =  100 , loss_val =  0.074846104
# epochs =  22 , step =  200 , loss_val =  0.0402876
# epochs =  22 , step =  300 , loss_val =  0.05068625
# epochs =  22 , step =  400 , loss_val =  0.008032517
# epochs =  22 , step =  500 , loss_val =  0.0037549178
# epochs =  23 , step =  0 , loss_val =  0.012809094
# epochs =  23 , step =  100 , loss_val =  0.046370503
# epochs =  23 , step =  200 , loss_val =  0.0009773937
# epochs =  23 , step =  300 , loss_val =  0.0118655525
# epochs =  23 , step =  400 , loss_val =  0.02781839
# epochs =  23 , step =  500 , loss_val =  0.005169903
# epochs =  24 , step =  0 , loss_val =  0.003931891
# epochs =  24 , step =  100 , loss_val =  0.004778796
# epochs =  24 , step =  200 , loss_val =  0.015315814
# epochs =  24 , step =  300 , loss_val =  0.007477311
# epochs =  24 , step =  400 , loss_val =  0.004512483
# epochs =  24 , step =  500 , loss_val =  0.0043620784
# epochs =  25 , step =  0 , loss_val =  0.004708088
# epochs =  25 , step =  100 , loss_val =  0.0016036266
# epochs =  25 , step =  200 , loss_val =  0.012815259
# epochs =  25 , step =  300 , loss_val =  0.014731373
# epochs =  25 , step =  400 , loss_val =  0.010864534
# epochs =  25 , step =  500 , loss_val =  0.1081727
# epochs =  26 , step =  0 , loss_val =  0.01192192
# epochs =  26 , step =  100 , loss_val =  0.008705057
# epochs =  26 , step =  200 , loss_val =  0.0064310418
# epochs =  26 , step =  300 , loss_val =  0.0035630933
# epochs =  26 , step =  400 , loss_val =  0.008173967
# epochs =  26 , step =  500 , loss_val =  0.0029205822
# epochs =  27 , step =  0 , loss_val =  0.03768449
# epochs =  27 , step =  100 , loss_val =  0.0064491183
# epochs =  27 , step =  200 , loss_val =  0.0035185325
# epochs =  27 , step =  300 , loss_val =  0.0042545213
# epochs =  27 , step =  400 , loss_val =  0.007411126
# epochs =  27 , step =  500 , loss_val =  0.0007229367
# epochs =  28 , step =  0 , loss_val =  0.03183593
# epochs =  28 , step =  100 , loss_val =  0.0051430343
# epochs =  28 , step =  200 , loss_val =  0.012519342
# epochs =  28 , step =  300 , loss_val =  0.037997454
# epochs =  28 , step =  400 , loss_val =  0.00516192
# epochs =  28 , step =  500 , loss_val =  0.01920622
# epochs =  29 , step =  0 , loss_val =  0.0048880028
# epochs =  29 , step =  100 , loss_val =  0.0027064162
# epochs =  29 , step =  200 , loss_val =  0.0024091918
# epochs =  29 , step =  300 , loss_val =  0.008550573
# epochs =  29 , step =  400 , loss_val =  0.024876704
# epochs =  29 , step =  500 , loss_val =  0.01918256
#
# elapsed time =  0:12:38.380947
#
# Accuracy =  0.9852
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  148
#
# length of index_label_false_list 148

# %%
# index_label_prediction_list
print(index_label_prediction_list)
# Out:
# [[18, 3, 5], [33, 4, 0], [211, 5, 3], [247, 4, 6], [259, 6, 0], [340, 5, 3], [366, 6, 0], [445, 6, 0], [449, 3, 5], [543, 8, 7], [582, 8, 2], [659, 2, 1], [740, 4, 9], [844, 8, 7], [882, 9, 7], [938, 3, 5], [947, 8, 9], [1014, 6, 5], [1039, 7, 2], [1112, 4, 6], [1178, 4, 0], [1182, 6, 5], [1202, 8, 6], [1226, 7, 2], [1232, 9, 4], [1242, 4, 9], [1247, 9, 5], [1319, 8, 0], [1326, 7, 2], [1393, 5, 3], [1414, 9, 3], [1530, 8, 7], [1543, 7, 3], [1549, 4, 6], [1553, 9, 3], [1621, 0, 6], [1634, 4, 9], [1709, 9, 5], [1717, 8, 0], [1737, 5, 1], [1754, 7, 2], [1790, 2, 7], [1878, 8, 3], [1899, 8, 7], [1901, 9, 4], [2004, 8, 9], [2035, 5, 3], [2098, 2, 0], [2107, 8, 0], [2118, 6, 0], [2130, 4, 9], [2131, 6, 0], [2135, 6, 1], [2272, 8, 0], [2293, 9, 0], [2329, 0, 2], [2406, 9, 4], [2414, 9, 4], [2462, 2, 0], [2597, 5, 3], [2654, 6, 1], [2758, 8, 5], [2771, 4, 9], [2836, 4, 9], [2896, 8, 0], [2921, 3, 2], [2939, 9, 5], [2952, 3, 5], [2953, 3, 5], [2995, 6, 5], [3030, 6, 0], [3289, 8, 9], [3422, 6, 0], [3451, 7, 9], [3503, 9, 1], [3520, 6, 4], [3559, 8, 5], [3626, 8, 3], [3727, 8, 9], [3751, 7, 2], [3808, 7, 8], [3850, 9, 4], [3853, 6, 0], [3906, 1, 2], [3941, 4, 6], [4063, 6, 5], [4075, 8, 0], [4176, 2, 7], [4201, 1, 7], [4207, 8, 2], [4224, 9, 7], [4238, 7, 3], [4248, 2, 1], [4256, 3, 2], [4571, 6, 8], [4639, 8, 9], [4713, 2, 6], [4731, 8, 3], [4740, 3, 5], [4761, 9, 8], [4783, 4, 9], [4807, 8, 0], [4838, 6, 5], [4860, 4, 9], [4911, 4, 9], [4956, 8, 4], [5159, 4, 9], [5199, 6, 0], [5201, 4, 9], [5228, 6, 4], [5265, 6, 4], [5634, 2, 8], [5642, 1, 5], [5654, 7, 2], [5749, 8, 5], [5955, 3, 8], [5997, 5, 9], [6091, 9, 5], [6166, 9, 3], [6168, 9, 3], [6505, 9, 0], [6560, 9, 5], [6569, 3, 2], [6571, 9, 7], [6574, 2, 6], [6576, 7, 1], [6597, 0, 9], [6651, 0, 8], [6847, 6, 4], [7461, 6, 0], [8246, 3, 5], [8325, 0, 6], [8406, 4, 9], [8408, 8, 5], [8522, 8, 2], [8527, 4, 9], [9009, 7, 2], [9015, 7, 2], [9019, 7, 2], [9024, 7, 2], [9540, 1, 8], [9634, 0, 2], [9679, 6, 4], [9692, 9, 7], [9698, 6, 1], [9729, 5, 6], [9768, 2, 9], [9770, 5, 0]]
