# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-1-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From c:\users\hogeu\anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 30            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층, 5X5X32 필터
W2 = tf.Variable(tf.random_normal([8, 8, 1, 32], stddev=0.01))  
#W2 = tf.Variable(tf.random_normal([5, 5, 1, 32]))  
#b2 = tf.Variable(tf.constant(0.1, shape=[32]))  
b2 = tf.Variable(tf.random_normal([32])) 

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 14X14 크기를 가진 32개의 activation map을 flatten 시킴
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*32])

# %%
# 출력층
W3 = tf.Variable(tf.random_normal([14*14*32, 10], stddev=0.01))
#W3 = tf.Variable(tf.random_normal([14*14*32, 10]))
b3 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z3, 즉 softmax 에 들어가는 입력 값
Z3 = logits = tf.matmul(A2_flat, W3) + b3    # 선형회귀 값 Z3

y = A3 = tf.nn.softmax(Z3)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z3, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A3, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A3, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 50 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  3.649029
# epochs =  0 , step =  100 , loss_val =  0.53015685
# epochs =  0 , step =  200 , loss_val =  0.44654647
# epochs =  0 , step =  300 , loss_val =  0.3679787
# epochs =  0 , step =  400 , loss_val =  0.35614982
# epochs =  0 , step =  500 , loss_val =  0.2314774
# epochs =  1 , step =  0 , loss_val =  0.25495234
# epochs =  1 , step =  100 , loss_val =  0.13724323
# epochs =  1 , step =  200 , loss_val =  0.15393753
# epochs =  1 , step =  300 , loss_val =  0.18722485
# epochs =  1 , step =  400 , loss_val =  0.10956757
# epochs =  1 , step =  500 , loss_val =  0.13683228
# epochs =  2 , step =  0 , loss_val =  0.104502365
# epochs =  2 , step =  100 , loss_val =  0.08155568
# epochs =  2 , step =  200 , loss_val =  0.03917726
# epochs =  2 , step =  300 , loss_val =  0.10159628
# epochs =  2 , step =  400 , loss_val =  0.08992678
# epochs =  2 , step =  500 , loss_val =  0.08098793
# epochs =  3 , step =  0 , loss_val =  0.055960063
# epochs =  3 , step =  100 , loss_val =  0.08915074
# epochs =  3 , step =  200 , loss_val =  0.057281338
# epochs =  3 , step =  300 , loss_val =  0.065793194
# epochs =  3 , step =  400 , loss_val =  0.017355975
# epochs =  3 , step =  500 , loss_val =  0.06043396
# epochs =  4 , step =  0 , loss_val =  0.1449591
# epochs =  4 , step =  100 , loss_val =  0.08302977
# epochs =  4 , step =  200 , loss_val =  0.09794386
# epochs =  4 , step =  300 , loss_val =  0.058260217
# epochs =  4 , step =  400 , loss_val =  0.030053273
# epochs =  4 , step =  500 , loss_val =  0.02024055
# epochs =  5 , step =  0 , loss_val =  0.023261558
# epochs =  5 , step =  100 , loss_val =  0.11728301
# epochs =  5 , step =  200 , loss_val =  0.05782397
# epochs =  5 , step =  300 , loss_val =  0.065704085
# epochs =  5 , step =  400 , loss_val =  0.01394183
# epochs =  5 , step =  500 , loss_val =  0.03972681
# epochs =  6 , step =  0 , loss_val =  0.111366786
# epochs =  6 , step =  100 , loss_val =  0.082875445
# epochs =  6 , step =  200 , loss_val =  0.01648941
# epochs =  6 , step =  300 , loss_val =  0.06721995
# epochs =  6 , step =  400 , loss_val =  0.09091935
# epochs =  6 , step =  500 , loss_val =  0.07178607
# epochs =  7 , step =  0 , loss_val =  0.004302338
# epochs =  7 , step =  100 , loss_val =  0.02745785
# epochs =  7 , step =  200 , loss_val =  0.02903396
# epochs =  7 , step =  300 , loss_val =  0.066142775
# epochs =  7 , step =  400 , loss_val =  0.08578882
# epochs =  7 , step =  500 , loss_val =  0.0018948233
# epochs =  8 , step =  0 , loss_val =  0.021975288
# epochs =  8 , step =  100 , loss_val =  0.069425836
# epochs =  8 , step =  200 , loss_val =  0.023592733
# epochs =  8 , step =  300 , loss_val =  0.023027394
# epochs =  8 , step =  400 , loss_val =  0.039011937
# epochs =  8 , step =  500 , loss_val =  0.032160316
# epochs =  9 , step =  0 , loss_val =  0.009806989
# epochs =  9 , step =  100 , loss_val =  0.048425492
# epochs =  9 , step =  200 , loss_val =  0.10264597
# epochs =  9 , step =  300 , loss_val =  0.0015599695
# epochs =  9 , step =  400 , loss_val =  0.03063216
# epochs =  9 , step =  500 , loss_val =  0.058316913
# epochs =  10 , step =  0 , loss_val =  0.049551424
# epochs =  10 , step =  100 , loss_val =  0.04323189
# epochs =  10 , step =  200 , loss_val =  0.017209858
# epochs =  10 , step =  300 , loss_val =  0.06269354
# epochs =  10 , step =  400 , loss_val =  0.03165805
# epochs =  10 , step =  500 , loss_val =  0.007873378
# epochs =  11 , step =  0 , loss_val =  0.036382623
# epochs =  11 , step =  100 , loss_val =  0.019076614
# epochs =  11 , step =  200 , loss_val =  0.032517552
# epochs =  11 , step =  300 , loss_val =  0.015055503
# epochs =  11 , step =  400 , loss_val =  0.013412659
# epochs =  11 , step =  500 , loss_val =  0.002143967
# epochs =  12 , step =  0 , loss_val =  0.048754998
# epochs =  12 , step =  100 , loss_val =  0.009260813
# epochs =  12 , step =  200 , loss_val =  0.011441325
# epochs =  12 , step =  300 , loss_val =  0.0160509
# epochs =  12 , step =  400 , loss_val =  0.0063379854
# epochs =  12 , step =  500 , loss_val =  0.006635943
# epochs =  13 , step =  0 , loss_val =  0.010850289
# epochs =  13 , step =  100 , loss_val =  0.0065910895
# epochs =  13 , step =  200 , loss_val =  0.01381688
# epochs =  13 , step =  300 , loss_val =  0.009080546
# epochs =  13 , step =  400 , loss_val =  0.04985358
# epochs =  13 , step =  500 , loss_val =  0.007814985
# epochs =  14 , step =  0 , loss_val =  0.00875749
# epochs =  14 , step =  100 , loss_val =  0.0108829
# epochs =  14 , step =  200 , loss_val =  0.0110855885
# epochs =  14 , step =  300 , loss_val =  0.0062608435
# epochs =  14 , step =  400 , loss_val =  0.0029529543
# epochs =  14 , step =  500 , loss_val =  0.016922828
# epochs =  15 , step =  0 , loss_val =  0.007832008
# epochs =  15 , step =  100 , loss_val =  0.0040709935
# epochs =  15 , step =  200 , loss_val =  0.0040770755
# epochs =  15 , step =  300 , loss_val =  0.043014728
# epochs =  15 , step =  400 , loss_val =  0.025931306
# epochs =  15 , step =  500 , loss_val =  0.016287334
# epochs =  16 , step =  0 , loss_val =  0.0035052877
# epochs =  16 , step =  100 , loss_val =  0.023031592
# epochs =  16 , step =  200 , loss_val =  0.00070389546
# epochs =  16 , step =  300 , loss_val =  0.015395081
# epochs =  16 , step =  400 , loss_val =  0.014627077
# epochs =  16 , step =  500 , loss_val =  0.0018389416
# epochs =  17 , step =  0 , loss_val =  0.010401167
# epochs =  17 , step =  100 , loss_val =  0.005387981
# epochs =  17 , step =  200 , loss_val =  0.0022515692
# epochs =  17 , step =  300 , loss_val =  0.0146227935
# epochs =  17 , step =  400 , loss_val =  0.017668795
# epochs =  17 , step =  500 , loss_val =  0.0138760125
# epochs =  18 , step =  0 , loss_val =  0.010235436
# epochs =  18 , step =  100 , loss_val =  0.004196062
# epochs =  18 , step =  200 , loss_val =  0.0026066343
# epochs =  18 , step =  300 , loss_val =  0.0004188055
# epochs =  18 , step =  400 , loss_val =  0.032165743
# epochs =  18 , step =  500 , loss_val =  0.019513126
# epochs =  19 , step =  0 , loss_val =  0.0026657071
# epochs =  19 , step =  100 , loss_val =  0.0010967769
# epochs =  19 , step =  200 , loss_val =  0.021702308
# epochs =  19 , step =  300 , loss_val =  0.0010660792
# epochs =  19 , step =  400 , loss_val =  0.051592845
# epochs =  19 , step =  500 , loss_val =  0.0025059527
# epochs =  20 , step =  0 , loss_val =  0.006392158
# epochs =  20 , step =  100 , loss_val =  0.002929427
# epochs =  20 , step =  200 , loss_val =  0.0037712436
# epochs =  20 , step =  300 , loss_val =  0.003510534
# epochs =  20 , step =  400 , loss_val =  0.00817597
# epochs =  20 , step =  500 , loss_val =  0.006598401
# epochs =  21 , step =  0 , loss_val =  0.0029794395
# epochs =  21 , step =  100 , loss_val =  0.0004966668
# epochs =  21 , step =  200 , loss_val =  0.0015055973
# epochs =  21 , step =  300 , loss_val =  0.0029669236
# epochs =  21 , step =  400 , loss_val =  0.007711536
# epochs =  21 , step =  500 , loss_val =  0.0032347338
# epochs =  22 , step =  0 , loss_val =  0.00315429
# epochs =  22 , step =  100 , loss_val =  0.005404751
# epochs =  22 , step =  200 , loss_val =  0.0039061683
# epochs =  22 , step =  300 , loss_val =  0.001703109
# epochs =  22 , step =  400 , loss_val =  0.005250649
# epochs =  22 , step =  500 , loss_val =  0.0004003853
# epochs =  23 , step =  0 , loss_val =  0.0015634794
# epochs =  23 , step =  100 , loss_val =  0.007971668
# epochs =  23 , step =  200 , loss_val =  0.034664437
# epochs =  23 , step =  300 , loss_val =  0.010539513
# epochs =  23 , step =  400 , loss_val =  0.033657048
# epochs =  23 , step =  500 , loss_val =  0.009684298
# epochs =  24 , step =  0 , loss_val =  0.0016140902
# epochs =  24 , step =  100 , loss_val =  0.0013123474
# epochs =  24 , step =  200 , loss_val =  0.037562795
# epochs =  24 , step =  300 , loss_val =  0.01577635
# epochs =  24 , step =  400 , loss_val =  0.0029244304
# epochs =  24 , step =  500 , loss_val =  0.0031355375
# epochs =  25 , step =  0 , loss_val =  0.013205278
# epochs =  25 , step =  100 , loss_val =  0.0011793898
# epochs =  25 , step =  200 , loss_val =  0.001486648
# epochs =  25 , step =  300 , loss_val =  0.0018462745
# epochs =  25 , step =  400 , loss_val =  0.005628492
# epochs =  25 , step =  500 , loss_val =  0.001212976
# epochs =  26 , step =  0 , loss_val =  0.0005387783
# epochs =  26 , step =  100 , loss_val =  0.00036420132
# epochs =  26 , step =  200 , loss_val =  0.0008953107
# epochs =  26 , step =  300 , loss_val =  0.0019479883
# epochs =  26 , step =  400 , loss_val =  0.00068835437
# epochs =  26 , step =  500 , loss_val =  4.5312634e-05
# epochs =  27 , step =  0 , loss_val =  0.0023644387
# epochs =  27 , step =  100 , loss_val =  4.7540972e-05
# epochs =  27 , step =  200 , loss_val =  0.012628978
# epochs =  27 , step =  300 , loss_val =  0.0008744264
# epochs =  27 , step =  400 , loss_val =  0.0036511624
# epochs =  27 , step =  500 , loss_val =  0.007866516
# epochs =  28 , step =  0 , loss_val =  0.0011366556
# epochs =  28 , step =  100 , loss_val =  0.004474566
# epochs =  28 , step =  200 , loss_val =  0.0005352715
# epochs =  28 , step =  300 , loss_val =  0.002290684
# epochs =  28 , step =  400 , loss_val =  0.0047585964
# epochs =  28 , step =  500 , loss_val =  0.0056196656
# epochs =  29 , step =  0 , loss_val =  0.00020379714
# epochs =  29 , step =  100 , loss_val =  0.019516915
# epochs =  29 , step =  200 , loss_val =  0.00033328802
# epochs =  29 , step =  300 , loss_val =  0.0005849145
# epochs =  29 , step =  400 , loss_val =  0.0023143028
# epochs =  29 , step =  500 , loss_val =  0.0009961859
#
# elapsed time =  0:16:50.723982
#
# Accuracy =  0.9891
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  109
#
# length of index_label_false_list 109
