# %% [markdown]
# 머신러닝의 가장 중요한 사실
#
# 머신러닝은 반드시 데이터가 있어야 한다
#
# Data mining 과 머신러닝의 차이
# Data mining 데이터를 이용하여 데이터의 특성을 뽑아냄 current set(현재 데이터)에 집중(통계학에 근접)
# 머신러닝은 저 data mining을 바탕으로 예측이 들어감
# 그 이유때문에 머신러닝에서는 평가지표가 만드시 필요함
# 딥러닝은 머신러닝을 구현하는 방법(알고리즘)에 따라서 나뉜다.
#
# 머신러닝의 장단점
#
# - 장점
# 정밀한 데이터 공정이 가능함
#
#
# - 단점
# 과적합(overfitting)이 발생한다
# 123 4
# 234 5
# 오버피팅을 줄여야한다
# - 오버피팅이란?
# 주어진 데이터에만 포커싱이 됨
# 경험하지 않은 데이터에 대해서는 맞추지 못한다
# - 해결법 : 데이터를 다양하게 제공 - 데이터의 다양성의 범위설정이 중요한문제
# 데이터 수집이 매우 어려움
#
# 중요 : 데이터의 다양성확보

# %% [markdown]
# - 머신러닝의 종류
#
# 지도학습에는 정답이 포함되있다
# 입력데이터와 정답의 유추관계
#
# 비지도 학습 오직 입력데이터만 존재
# 패턴을 학습
#
# 강화학습 데이터가 없음 데이터를 만들어서 학습
#
# 지도학습이 가장 많다
# 이유; 정답이 있으면 예측의 정확도를 판단할 수 있다
#
# 분류를 가장많이 이용 (참이냐 거짓이냐)
#
# 지도학습
#
# 데이터를 찾고 만들어주는 작업이 전체 작업의 50프로
# 연속적인 값을 갖고 데이터 분석 regression
# 데이터는 평균으로 돌아가려는 경향이 있다 그래서 회귀라 한다
# (단 데이터의 풀이 커야한다)
#
# 불연속적인 데이터의 분석 classification
#
#
# 비지도학습
#
# 트레이닝 데이터에 정답은 없고 입력데이터만 있기에 데이터의 패턴 특성등을 학습(백화점 상품시스템)
# 단점 데이터의 신뢰도가 떨어짐
#
#
# 강화학습
#
# agent and enviroment
# 에이전트가 환경내에서 보상이 최대화대는 방향으로 행동을 수행하도록 학습하는 기법
# 최소한의 액션과 시간으로 최대한의 보상을 얻는법을 찾는것이 핵심
# 시간 간격에 따라서 결과값이 틀려짐(그래서 끝이 있는것에는 강화학습을 적용할수 있습)
#
#
#
# transfer learning
# 전이학습 : 기존에 있는 모델을 자신의 데이터에 맞게 바꿔서 개발하는 방법
# predefined 기존에 있는
# fine tuning 미세하게 끝에있는 알고리즘을 바꿈
#
# XAI 설명가능한 인공지능
# 숫자와 확률로만 설명해주는 기존의 인공지능과 달리 근거를 판단하여 설명해주는 인공지능
#
# fairness
# 데이터의 공정성 확보
